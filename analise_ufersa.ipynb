# %% [markdown]
# #### 01 - Quantas disciplinas foram ofertadas pela Universidade desde o início do funcionamento (2007) até o período 2019.1?
# Foram ofertadas um total de 25673 disciplinas desde 2007 até 2019. Apresentadas a seguir nas seguintes disposições, por ano e por período.

# %%
#*-- coding utf8 --*

import matplotlib.pyplot as plt
import csv, seaborn as sb

x = []
y = []

with open('output/Q1_Ano.csv', 'r') as csvfile:
    plots= csv.reader(csvfile, delimiter=',')
    for row in plots:
        x.append(int(row[0]))
        y.append(int(row[1]))

plt.figure(figsize=(15,10))
plt.title('Dados: Disciplinas por Ano')
plt.xlabel('Ano')
plt.ylabel('Número de Disciplinas')

splot = sb.barplot(x, y)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., 
    p.get_height()), ha = 'center', va = 'center',
    xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %% [markdown]
# #### Há algumas observações interessantes que precisam ser citadas:
# * A baixíssima oferta de disciplinas entre 2007 e 2009, com uma ausência de registros em 2008;
# * O crescimento relativamente constante do número de disciplinas no decorrer dos anos, o que dá indícios da expansão da instituição;
# * A quase ausência de registros em 2019, o que pode indicar um problema na coleta quanto ao tempo, é provável que a coleta tenha sido realizada quando os dados de 2019 ainda não estavam disponíveis.

# %%
import matplotlib.pyplot as plt
import csv, seaborn as sb

x=[]
y=[]

with open('output/Q1_Periodo.csv', 'r') as csvfile:
    plots= csv.reader(csvfile, delimiter=',')
    for row in plots:
        x.append(row[0])
        y.append(int(row[1]))


plt.figure(figsize=(25,10))
plt.title('Dados: Disciplinas por Período')
plt.xlabel('Período')
plt.ylabel('Número de Disciplinas')

splot = sb.barplot(x, y)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., 
    p.get_height()), ha = 'center', va = 'center',
    xytext = (0, 10), textcoords = 'offset points')

plt.show()

# %% [markdown]
# #### Sobre a oferta de disciplinas distribuída durante os períodos:
# * É interessante citar que existem períodos fora das convenções de numeração de semestre, geralmente 1 e 2, os chamados períodos suplementares;

# %% [markdown]
# #### 02 - Quais as disciplinas mais ofertadas da UFERSA?
# * No gráfico abaixo são mostradas as 3 disciplinas mais ofertadas da UFERSA, são também as únicas ofertadas mais de 300 vezes. Isso indica uma grande demanda por essas disciplinas que pode estar ligada ao número médio de vezes que um aluno precisa cursá-la para conseguir aprovação.

# %%
import matplotlib.pyplot as plt
import csv, seaborn as sb

x=[]
y=[]

with open('output/Q2.csv', 'r') as csvfile:
    plots = list(csv.reader(csvfile, delimiter=','))
    for i in plots[0:3]:
        y.append(i[1])
        x.append(int(i[0]))

plt.figure(figsize=(20,5))
plt.title('Dados: Disciplinas mais ofertadas')
plt.ylabel('Disciplinas')
plt.xlabel('Vezes ofertada')

splot = sb.barplot(x, y)
for p in splot.patches:
    splot.annotate(format(p.get_width(), '.0f'), #, # Valores Numéricos
                       (p.get_x() + p.get_width(), p.get_y() + p.get_height() / 2), 
                       ha = 'center', va = 'center',
                       xytext = (10, 0), 
                       textcoords = 'offset points')

# %% [markdown]
# * Abaixo estão as 14 disciplinas com mais de 200 registros de oferta.

# %%
import matplotlib.pyplot as plt
import csv, seaborn as sb

x=[]
y=[]

with open('output/Q2.csv', 'r') as csvfile:
    plots = list(csv.reader(csvfile, delimiter=','))
    for i in plots[0:14]:
        y.append(i[1])
        x.append(int(i[0]))

plt.figure(figsize=(20,15))
plt.title('Dados: Disciplinas mais ofertadas')
plt.ylabel('Disciplinas')
plt.xlabel('Vezes ofertada')

splot = sb.barplot(x, y)
for p in splot.patches:
    splot.annotate(format(p.get_width(), '.0f'), #, # Valores Numéricos
                       (p.get_x() + p.get_width(), p.get_y() + p.get_height() / 2), 
                       ha = 'center', va = 'center',
                       xytext = (10, 0), 
                       textcoords = 'offset points')

# %% [markdown]
# * E, por fim, estão as 34 disciplinas com mais de 100 registros de oferta.

# %%
import matplotlib.pyplot as plt
import csv, seaborn as sb

x=[]
y=[]

with open('output/Q2.csv', 'r') as csvfile:
    plots = list(csv.reader(csvfile, delimiter=','))
    for i in plots[0:34]:
        y.append(i[1])
        x.append(int(i[0]))

plt.figure(figsize=(20,20))
plt.title('Dados: Disciplinas mais ofertadas')
plt.ylabel('Número de Disciplinas')

splot = sb.barplot(x, y)
for p in splot.patches:
    splot.annotate(format(p.get_width(), '.0f'), #, # Valores Numéricos
                       (p.get_x() + p.get_width(), p.get_y() + p.get_height() / 2), 
                       ha = 'center', va = 'center',
                       xytext = (10, 0), 
                       textcoords = 'offset points')

# %% [markdown]
# #### 03 - Qual(ais) o(s) dia(s) e horário(s) em que há mais disciplinas ofertadas?
# * Divisão das disciplinas entre EAD, presenciais com horários definidos e presenciais sem horários;
# * Horários mais usados.

# %%
import matplotlib.pyplot as plt

with open('output/Q3_EAD.csv', 'r') as csvfile:
    ead = list(csv.reader(csvfile, delimiter=','))

with open('output/Q3_Disc_C_Hor.csv', 'r') as csvfile:
    disc = list(csv.reader(csvfile, delimiter=','))

with open('output/Q3_Nao_EAD.csv', 'r') as csvfile:
    n_ead = list(csv.reader(csvfile, delimiter=','))

y = [len(ead), len(n_ead), len(disc)]

plt.figure(1, figsize=(10,10))
plt.title('Disciplinas Presenciais e EAD')

source_pie = plt.pie(y, 
                     #labels=['Disciplinas com horários', 'Disciplinas sem horários', 'Disciplinas EAD'], 
                     labels=['Disciplinas EAD', 'Disciplinas sem horários', 'Disciplinas com horários'], 
                     autopct='%1.2f%%'
                    )

#sb.barplot(['EAD','Presenciais sem horário','Presenciais'], y)

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sb

x = []
y = []

with open('output/Q3_Hor_Disc.csv', 'r') as csvfile:
    disc = list(csv.reader(csvfile, delimiter=','))
    for row in disc[0:3]:
        x.append(row[1])
        y.append(int(row[0]))


plt.figure(figsize=(6,7))
plt.title('Top 3 horários mais usados.')
plt.xlabel('Horários')
plt.ylabel('Número de vezes usado.')

splot = sb.barplot(x, y)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., 
    p.get_height()), ha = 'center', va = 'center',
    xytext = (0, 10), textcoords = 'offset points')

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import matplotlib.pyplot as plt
import seaborn as sb

x = []
y = []

with open('output/Q3_Hor_Disc.csv', 'r') as csvfile:
    disc = list(csv.reader(csvfile, delimiter=','))
    for row in disc[0:10]:
        x.append(row[1])
        y.append(int(row[0]))


plt.figure(figsize=(10,10))
plt.title('Top 10 horários mais usados.')
plt.xlabel('Horários')
plt.ylabel('Número de vezes usado.')

splot = sb.barplot(x, y)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., 
    p.get_height()), ha = 'center', va = 'center',
    xytext = (0, 10), textcoords = 'offset points')

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# * Levando em consideração que a maior parte das disciplinas são presenciais e que possuem horários definidos é provavel que os primeiros horários de segunda-feira e da quarta-feira possuam o maior fluxo de alunos na universidade.
