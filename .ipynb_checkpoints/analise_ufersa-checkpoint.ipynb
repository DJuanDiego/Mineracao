# %% [markdown]
# #### 01 - Quantas disciplinas foram ofertadas pela Universidade desde o início do funcionamento (2007) até o período 2019.1?
# Foram ofertadas um total de 25673 disciplinas desde 2007 até 2019. Apresentadas a seguir nas seguintes disposições, por ano e por período.

# %%
#*-- coding utf8 --*

import matplotlib.pyplot as plt
import csv, seaborn as sb

x = []
y = []

with open('output/Q1_Ano.csv', 'r') as csvfile:
    plots= csv.reader(csvfile, delimiter=',')
    for row in plots:
        x.append(int(row[0]))
        y.append(int(row[1]))

plt.figure(figsize=(15,10))
plt.title('Dados: Disciplinas por Ano')
plt.xlabel('Ano')
plt.ylabel('Número de Disciplinas')
#plt.plot(x, y, 'go', scaley=True, linestyle="dashed", linewidth=2, markersize=15)

splot = sb.barplot(x, y)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.0f'), (p.get_x() + p.get_width() / 2., 
    p.get_height()), ha = 'center', va = 'center',
    xytext = (0, 10), textcoords = 'offset points')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv

x=[]
y=[]

with open('output/Q1_Periodo.csv', 'r') as csvfile:
    plots= csv.reader(csvfile, delimiter=',')
    for row in plots:
        x.append(row[0])
        y.append(int(row[1]))


plt.figure(figsize=(20,10))
plt.title('Dados: Disciplinas por Período')
plt.xlabel('Período')
plt.ylabel('Número de Disciplinas')
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-206-a7a3034a32b9> in <module>
#      16 plt.xlabel('Período')
#      17 plt.ylabel('Número de Disciplinas')
# ---> 18 plt.colorbar(x,y)
#      19 plt.show()
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/pyplot.py in colorbar(mappable, cax, ax, **kw)
#    2085     if ax is None:
#    2086         ax = gca()
# -> 2087     ret = gcf().colorbar(mappable, cax=cax, ax=ax, **kw)
#    2088     return ret
#    2089 colorbar.__doc__ = matplotlib.colorbar.colorbar_doc
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/figure.py in colorbar(self, mappable, cax, ax, use_gridspec, **kw)
#    2213                              'panchor']
#    2214         cb_kw = {k: v for k, v in kw.items() if k not in NON_COLORBAR_KEYS}
# -> 2215         cb = cbar.colorbar_factory(cax, mappable, **cb_kw)
#    2216
#    2217         self.sca(current_ax)
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/colorbar.py in colorbar_factory(cax, mappable, **kwargs)
#    1638         cb = ColorbarPatch(cax, mappable, **kwargs)
#    1639     else:
# -> 1640         cb = Colorbar(cax, mappable, **kwargs)
#    1641
#    1642     cid = mappable.callbacksSM.connect('changed', cb.on_mappable_changed)
#
# /opt/anaconda/lib/python3.7/site-packages/matplotlib/colorbar.py in __init__(self, ax, mappable, **kw)
#    1156         # Ensure the given mappable's norm has appropriate vmin and vmax set
#    1157         # even if mappable.draw has not yet been called.
# -> 1158         if mappable.get_array() is not None:
#    1159             mappable.autoscale_None()
#    1160
#
# AttributeError: 'list' object has no attribute 'get_array'

# %%
import matplotlib.pyplot as plt
import csv, seaborn as sb

x=[]
y=[]

with open('output/Q1_Periodo.csv', 'r') as csvfile:
    plots= csv.reader(csvfile, delimiter=',')
    for row in plots:
        x.append(row[0])
        y.append(int(row[1]))

plt.figure(figsize=(20,10))
plt.title('Dados: Disciplinas por Período')
plt.xlabel('Ano')
plt.ylabel('Número de Disciplinas')
sb.barplot(x,y)
#plt.plot(x,y, 'o')

# %%
import csv, pandas as pd
import matplotlib as mpl
import seaborn as sb

periodo = pd.read_csv("./output/Q1_Periodo.csv", names = ['QUANTIDADE','PERIODO'])

x = periodo.PERIODO
y = periodo.QUANTIDADE


mpl.pyplot.figure(figsize=(25,30))
#mpl.pyplot.bar(x,y)
#mpl.pyplot.show()
sb.barplot(x,y, data=periodo)
